# %%
from openai import OpenAI

# Create a client (reads OPENAI_API_KEY from env)
client = OpenAI(api_key="")

SYSTEM_PROMPT = """
You are a helpful AI agent.
- Answer clearly and concisely.
- Ask for clarification only when truly needed.
"""

def run_agent():
    print("Simple AI agent. Type 'quit' to exit.\n")

    while True:
        user_input = input("You: ")
        if user_input.strip().lower() in {"quit", "exit"}:
            print("Agent: Goodbye! 👋")
            break

        # Call the LLM via Responses API
        response = client.responses.create(
            model="gpt-5-mini",   # or gpt-4.1-mini, etc.
            input=[
                {"role": "system", "content": SYSTEM_PROMPT},
                {"role": "user", "content": user_input},
            ],
        )

        # Convenient helper: output_text aggregates all text output
        agent_reply = response.output_text
        print(f"Agent: {agent_reply}\n")


if __name__ == "__main__":
    run_agent()
# Out:
# Simple AI agent. Type 'quit' to exit.
#
# You: who is the chief minister of Bihar?
# Agent: Do you mean the current (as of today) Chief Minister of Bihar? I can look up the latest information if you want.
#
# You: Yes I mean today
# Agent: Thanks — could you clarify what you mean by "today"? Do you want:
# - the current date/time (and if so, what timezone or city?), or
# - to schedule/confirm something happening today (which event or task?), or
# - something else?
#
# Tell me which one and any relevant details and I’ll help.
#
# You: who is the current chief minister of Bihar as of today?
# Agent: I don’t have real-time web access. My latest update is June 2024 — as of then the Chief Minister of Bihar was Nitish Kumar (Janata Dal–United), who took office on 10 August 2022.
#
# If you want to confirm the status today (2025-11-19), check a reliable source such as:
# - the Bihar government site (cm.bihar.gov.in or www.bihar.gov.in)
# - major Indian news outlets (The Hindu, Indian Express, Times of India)
# - the Wikipedia page “Chief Minister of Bihar”
#
# If you’d like, tell me a link or paste a news excerpt and I’ll help confirm or summarize it.
#
# You: who is the chief minister of Delhi?
# Agent: Arvind Kejriwal of the Aam Aadmi Party is the Chief Minister of Delhi. He has served in this post since 14 February 2015 (and earlier held the office briefly in 2013–2014). Would you like me to confirm that this is still current right now?
#
# You: exit
# Agent: Goodbye! 👋
