# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.23.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.7.4)

# %%
from huggingface_hub import HfApi

# Initialize the Hugging Face API
api = HfApi()

# Fetch the list of models
models = api.list_models()

# Print details of the models
for model in models:
    print(f"Model ID: {model.modelId}")
    print(f"Model Name: {model.modelId}")
    print(f"Pipeline Tag: {model.pipeline_tag}")
    print(f"Tags: {model.tags}")
    print("-" * 80)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet50d.a1_in1k
# Model Name: timm/resnet50d.a1_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet50d.a2_in1k
# Model Name: timm/resnet50d.a2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet50d.a3_in1k
# Model Name: timm/resnet50d.a3_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet50d.gluon_in1k
# Model Name: timm/resnet50d.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet50d.ra2_in1k
# Model Name: timm/resnet50d.ra2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet50s.gluon_in1k
# Model Name: timm/resnet50s.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101.a1_in1k
# Model Name: timm/resnet101.a1_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: mrm8488/electricidad-small-finetuned-diagTrast
# Model Name: mrm8488/electricidad-small-finetuned-diagTrast
# Pipeline Tag: text-classification
# Tags: ['transformers', 'pytorch', 'tensorboard', 'electra', 'text-classification', 'generated_from_trainer', 'autotrain_compatible', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101.a1h_in1k
# Model Name: timm/resnet101.a1h_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Muzto/jp1
# Model Name: Muzto/jp1
# Pipeline Tag: None
# Tags: ['license:openrail', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101.a2_in1k
# Model Name: timm/resnet101.a2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101.a3_in1k
# Model Name: timm/resnet101.a3_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101.gluon_in1k
# Model Name: timm/resnet101.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101.tv2_in1k
# Model Name: timm/resnet101.tv2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'license:bsd-3-clause', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101.tv_in1k
# Model Name: timm/resnet101.tv_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'license:bsd-3-clause', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101c.gluon_in1k
# Model Name: timm/resnet101c.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101d.gluon_in1k
# Model Name: timm/resnet101d.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: candysai/ai
# Model Name: candysai/ai
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101d.ra2_in1k
# Model Name: timm/resnet101d.ra2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet101s.gluon_in1k
# Model Name: timm/resnet101s.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: mrm8488/electricidad-base-ft-diagTrast
# Model Name: mrm8488/electricidad-base-ft-diagTrast
# Pipeline Tag: text-classification
# Tags: ['transformers', 'pytorch', 'tensorboard', 'electra', 'text-classification', 'generated_from_trainer', 'autotrain_compatible', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152.a1_in1k
# Model Name: timm/resnet152.a1_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152.a1h_in1k
# Model Name: timm/resnet152.a1h_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152.a2_in1k
# Model Name: timm/resnet152.a2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152.a3_in1k
# Model Name: timm/resnet152.a3_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152.gluon_in1k
# Model Name: timm/resnet152.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: UserNotFoundSession/Test
# Model Name: UserNotFoundSession/Test
# Pipeline Tag: None
# Tags: ['license:openrail', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152.tv2_in1k
# Model Name: timm/resnet152.tv2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'license:bsd-3-clause', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152.tv_in1k
# Model Name: timm/resnet152.tv_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'license:bsd-3-clause', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152c.gluon_in1k
# Model Name: timm/resnet152c.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152d.gluon_in1k
# Model Name: timm/resnet152d.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: amaydle/mergex-v2
# Model Name: amaydle/mergex-v2
# Pipeline Tag: text2text-generation
# Tags: ['transformers', 'pytorch', 'tensorboard', 't5', 'text2text-generation', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: YiYiXu/control_out
# Model Name: YiYiXu/control_out
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152d.ra2_in1k
# Model Name: timm/resnet152d.ra2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: sgoodfriend/ppo-enc-dec-MicrortsDefeatCoacAIShaped-v3-diverseBots
# Model Name: sgoodfriend/ppo-enc-dec-MicrortsDefeatCoacAIShaped-v3-diverseBots
# Pipeline Tag: reinforcement-learning
# Tags: ['rl-algo-impls', 'MicrortsDefeatCoacAIShaped-v3', 'ppo', 'deep-reinforcement-learning', 'reinforcement-learning', 'model-index', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet152s.gluon_in1k
# Model Name: timm/resnet152s.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Stromello/DialoGPT-medium-ZeroTwo
# Model Name: Stromello/DialoGPT-medium-ZeroTwo
# Pipeline Tag: text-generation
# Tags: ['transformers', 'pytorch', 'gpt2', 'text-generation', 'conversational', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: lakshmiv/GenerAd-AI
# Model Name: lakshmiv/GenerAd-AI
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnet200d.ra2_in1k
# Model Name: timm/resnet200d.ra2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: christinekwon/13b-mindset
# Model Name: christinekwon/13b-mindset
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetaa50.a1h_in1k
# Model Name: timm/resnetaa50.a1h_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1904.11486', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Ballbetlogluga90/Model
# Model Name: Ballbetlogluga90/Model
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: data-corentinv/bloom-1b7-lora-ads
# Model Name: data-corentinv/bloom-1b7-lora-ads
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetaa50d.d_in12k
# Model Name: timm/resnetaa50d.d_in12k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1904.11486', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: alesthehuman/q-Taxi-v3
# Model Name: alesthehuman/q-Taxi-v3
# Pipeline Tag: reinforcement-learning
# Tags: ['Taxi-v3', 'q-learning', 'reinforcement-learning', 'custom-implementation', 'model-index', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetaa50d.sw_in12k
# Model Name: timm/resnetaa50d.sw_in12k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1904.11486', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetaa50d.sw_in12k_ft_in1k
# Model Name: timm/resnetaa50d.sw_in12k_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1904.11486', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetaa101d.sw_in12k
# Model Name: timm/resnetaa101d.sw_in12k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1904.11486', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetaa101d.sw_in12k_ft_in1k
# Model Name: timm/resnetaa101d.sw_in12k_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1904.11486', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetblur50.bt_in1k
# Model Name: timm/resnetblur50.bt_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1904.11486', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetrs50.tf_in1k
# Model Name: timm/resnetrs50.tf_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2103.07579', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: RandenBanuelos/ppo-LunarLander-v2
# Model Name: RandenBanuelos/ppo-LunarLander-v2
# Pipeline Tag: reinforcement-learning
# Tags: ['stable-baselines3', 'LunarLander-v2', 'deep-reinforcement-learning', 'reinforcement-learning', 'model-index', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetrs101.tf_in1k
# Model Name: timm/resnetrs101.tf_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2103.07579', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetrs152.tf_in1k
# Model Name: timm/resnetrs152.tf_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2103.07579', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: akadhim-ai/sd_martin_valen-model-v1-2_400
# Model Name: akadhim-ai/sd_martin_valen-model-v1-2_400
# Pipeline Tag: text-to-image
# Tags: ['diffusers', 'tensorboard', 'art', 'text-to-image', 'en', 'dataset:Ali-fb/martin_valen_dataset', 'license:openrail', 'autotrain_compatible', 'endpoints_compatible', 'diffusers:StableDiffusionPipeline', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Gisliany/sd_martin_valen-model-v1-2_400
# Model Name: Gisliany/sd_martin_valen-model-v1-2_400
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: telmo000/bloom-positive-reframing
# Model Name: telmo000/bloom-positive-reframing
# Pipeline Tag: text-generation
# Tags: ['text-generation', 'en', 'dataset:SALT-NLP/positive_reframing', 'arxiv:2204.02952', 'arxiv:1910.09700', 'license:bigscience-bloom-rail-1.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetrs200.tf_in1k
# Model Name: timm/resnetrs200.tf_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2103.07579', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetrs270.tf_in1k
# Model Name: timm/resnetrs270.tf_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2103.07579', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: jstmyownd/kanpiromix
# Model Name: jstmyownd/kanpiromix
# Pipeline Tag: None
# Tags: ['license:wtfpl', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetrs350.tf_in1k
# Model Name: timm/resnetrs350.tf_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2103.07579', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnetrs420.tf_in1k
# Model Name: timm/resnetrs420.tf_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2103.07579', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: kanak8278/electra-base-ner-food-recipe
# Model Name: kanak8278/electra-base-ner-food-recipe
# Pipeline Tag: token-classification
# Tags: ['transformers', 'pytorch', 'tensorboard', 'electra', 'token-classification', 'generated_from_trainer', 'license:apache-2.0', 'autotrain_compatible', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50_32x4d.a1_in1k
# Model Name: timm/resnext50_32x4d.a1_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50_32x4d.a1h_in1k
# Model Name: timm/resnext50_32x4d.a1h_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50_32x4d.a2_in1k
# Model Name: timm/resnext50_32x4d.a2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50_32x4d.a3_in1k
# Model Name: timm/resnext50_32x4d.a3_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50_32x4d.fb_ssl_yfcc100m_ft_in1k
# Model Name: timm/resnext50_32x4d.fb_ssl_yfcc100m_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1905.00546', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50_32x4d.fb_swsl_ig1b_ft_in1k
# Model Name: timm/resnext50_32x4d.fb_swsl_ig1b_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1905.00546', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50_32x4d.gluon_in1k
# Model Name: timm/resnext50_32x4d.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50_32x4d.ra_in1k
# Model Name: timm/resnext50_32x4d.ra_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Tmontana1111/GenerAd-AI
# Model Name: Tmontana1111/GenerAd-AI
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50_32x4d.tv2_in1k
# Model Name: timm/resnext50_32x4d.tv2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:bsd-3-clause', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50_32x4d.tv_in1k
# Model Name: timm/resnext50_32x4d.tv_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:bsd-3-clause', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext50d_32x4d.bt_in1k
# Model Name: timm/resnext50d_32x4d.bt_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x4d.fb_ssl_yfcc100m_ft_in1k
# Model Name: timm/resnext101_32x4d.fb_ssl_yfcc100m_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1905.00546', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x4d.fb_swsl_ig1b_ft_in1k
# Model Name: timm/resnext101_32x4d.fb_swsl_ig1b_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1905.00546', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x4d.gluon_in1k
# Model Name: timm/resnext101_32x4d.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x8d.fb_ssl_yfcc100m_ft_in1k
# Model Name: timm/resnext101_32x8d.fb_ssl_yfcc100m_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1905.00546', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x8d.fb_swsl_ig1b_ft_in1k
# Model Name: timm/resnext101_32x8d.fb_swsl_ig1b_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1905.00546', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: jimmyhezhang/distilbert-base-uncased-finetuned-emotion
# Model Name: jimmyhezhang/distilbert-base-uncased-finetuned-emotion
# Pipeline Tag: text-classification
# Tags: ['transformers', 'pytorch', 'tensorboard', 'distilbert', 'text-classification', 'generated_from_trainer', 'dataset:emotion', 'license:apache-2.0', 'model-index', 'autotrain_compatible', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x8d.fb_wsl_ig1b_ft_in1k
# Model Name: timm/resnext101_32x8d.fb_wsl_ig1b_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1805.00932', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: EleVicted/BG2
# Model Name: EleVicted/BG2
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x8d.tv2_in1k
# Model Name: timm/resnext101_32x8d.tv2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:bsd-3-clause', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Charmi06/Anomaly-Detection-CNN
# Model Name: Charmi06/Anomaly-Detection-CNN
# Pipeline Tag: None
# Tags: ['doi:10.57967/hf/0505', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x8d.tv_in1k
# Model Name: timm/resnext101_32x8d.tv_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:bsd-3-clause', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x16d.fb_ssl_yfcc100m_ft_in1k
# Model Name: timm/resnext101_32x16d.fb_ssl_yfcc100m_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1905.00546', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: ealtan/bloom-1b7-lora-ads
# Model Name: ealtan/bloom-1b7-lora-ads
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x16d.fb_swsl_ig1b_ft_in1k
# Model Name: timm/resnext101_32x16d.fb_swsl_ig1b_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1905.00546', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: carolinainmymind/Reinforce-v1
# Model Name: carolinainmymind/Reinforce-v1
# Pipeline Tag: reinforcement-learning
# Tags: ['CartPole-v1', 'reinforce', 'reinforcement-learning', 'custom-implementation', 'deep-rl-class', 'model-index', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: ish59/Crypto-Ish
# Model Name: ish59/Crypto-Ish
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x16d.fb_wsl_ig1b_ft_in1k
# Model Name: timm/resnext101_32x16d.fb_wsl_ig1b_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1805.00932', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: osman93/ppo-PyramidsTESTCOLAB
# Model Name: osman93/ppo-PyramidsTESTCOLAB
# Pipeline Tag: reinforcement-learning
# Tags: ['ml-agents', 'tensorboard', 'onnx', 'Pyramids', 'deep-reinforcement-learning', 'reinforcement-learning', 'ML-Agents-Pyramids', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_32x32d.fb_wsl_ig1b_ft_in1k
# Model Name: timm/resnext101_32x32d.fb_wsl_ig1b_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1805.00932', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:cc-by-nc-4.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: data-corentinv/bloom-fourthbrain-hackathon-1b7-lora-ads
# Model Name: data-corentinv/bloom-fourthbrain-hackathon-1b7-lora-ads
# Pipeline Tag: text2text-generation
# Tags: ['transformers', 'bloom', 'text-generation', 'fourthbrain', 'dtlb', 'text2text-generation', 'en', 'license:mit', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: derekepp/bart-samsum
# Model Name: derekepp/bart-samsum
# Pipeline Tag: text2text-generation
# Tags: ['transformers', 'pytorch', 'bart', 'text2text-generation', 'autotrain_compatible', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: leonbentre/ml
# Model Name: leonbentre/ml
# Pipeline Tag: None
# Tags: ['license:openrail', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: drumwell/sd_skatedeck-model-v1-2_400
# Model Name: drumwell/sd_skatedeck-model-v1-2_400
# Pipeline Tag: text-to-image
# Tags: ['diffusers', 'tensorboard', 'art', 'text-to-image', 'en', 'dataset:drumwell/skatedecks', 'license:openrail', 'autotrain_compatible', 'endpoints_compatible', 'diffusers:StableDiffusionPipeline', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: RamAnanth1/videocrafter-text2video
# Model Name: RamAnanth1/videocrafter-text2video
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_64x4d.c1_in1k
# Model Name: timm/resnext101_64x4d.c1_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Zekunli/flan-t5-base-da-multiwoz2.1_400-loss-ep100
# Model Name: Zekunli/flan-t5-base-da-multiwoz2.1_400-loss-ep100
# Pipeline Tag: text2text-generation
# Tags: ['transformers', 'pytorch', 't5', 'text2text-generation', 'generated_from_trainer', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_64x4d.gluon_in1k
# Model Name: timm/resnext101_64x4d.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: uaritm/T5_ukruen_qa_all_clean_10
# Model Name: uaritm/T5_ukruen_qa_all_clean_10
# Pipeline Tag: text2text-generation
# Tags: ['transformers', 'pytorch', 't5', 'text2text-generation', 'license:creativeml-openrail-m', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/resnext101_64x4d.tv_in1k
# Model Name: timm/resnext101_64x4d.tv_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'license:bsd-3-clause', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: jasonjones/GenerAd-AI
# Model Name: jasonjones/GenerAd-AI
# Pipeline Tag: text-generation
# Tags: ['text-generation', 'en', 'dataset:jasonjones/batman_product_ads', 'license:bigscience-openrail-m', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/senet154.gluon_in1k
# Model Name: timm/senet154.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1709.01507', 'arxiv:1512.03385', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Ameerah/Questionmark
# Model Name: Ameerah/Questionmark
# Pipeline Tag: None
# Tags: ['license:other', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Jiuzhouh/alpaca-13b-lora-graph-all
# Model Name: Jiuzhouh/alpaca-13b-lora-graph-all
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: mintii/dnd-monsters
# Model Name: mintii/dnd-monsters
# Pipeline Tag: None
# Tags: ['art', 'en', 'dataset:alan-txi/dnd-monsters', 'license:openrail', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: milan2000/GenerAd-AI
# Model Name: milan2000/GenerAd-AI
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnet50.a1_in1k
# Model Name: timm/seresnet50.a1_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1709.01507', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnet50.a2_in1k
# Model Name: timm/seresnet50.a2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1709.01507', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: jeffjamesqz/GenerAd-AI
# Model Name: jeffjamesqz/GenerAd-AI
# Pipeline Tag: None
# Tags: ['license:bigscience-openrail-m', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnet50.a3_in1k
# Model Name: timm/seresnet50.a3_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1709.01507', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnet50.ra2_in1k
# Model Name: timm/seresnet50.ra2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1709.01507', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnet152d.ra2_in1k
# Model Name: timm/seresnet152d.ra2_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1512.03385', 'arxiv:1709.01507', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: martomor/oasis-bloom
# Model Name: martomor/oasis-bloom
# Pipeline Tag: text-generation
# Tags: ['transformers', 'text-generation', 'en', 'dataset:tthoraldson/OasisLyrics', 'license:openrail', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: dhmeltzer/flan-t5-base_askscience-qg
# Model Name: dhmeltzer/flan-t5-base_askscience-qg
# Pipeline Tag: text2text-generation
# Tags: ['transformers', 'pytorch', 't5', 'text2text-generation', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnext26d_32x4d.bt_in1k
# Model Name: timm/seresnext26d_32x4d.bt_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1709.01507', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnext26t_32x4d.bt_in1k
# Model Name: timm/seresnext26t_32x4d.bt_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1709.01507', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: LennonTurner408/job_summaries_model
# Model Name: LennonTurner408/job_summaries_model
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnext50_32x4d.gluon_in1k
# Model Name: timm/seresnext50_32x4d.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1709.01507', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: verderis/reinforce-heli-01
# Model Name: verderis/reinforce-heli-01
# Pipeline Tag: reinforcement-learning
# Tags: ['Pixelcopter-PLE-v0', 'reinforce', 'reinforcement-learning', 'custom-implementation', 'deep-rl-class', 'model-index', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnext50_32x4d.racm_in1k
# Model Name: timm/seresnext50_32x4d.racm_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1709.01507', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnext101_32x4d.gluon_in1k
# Model Name: timm/seresnext101_32x4d.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1709.01507', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnext101_32x8d.ah_in1k
# Model Name: timm/seresnext101_32x8d.ah_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1709.01507', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: kiyoonkim/aag
# Model Name: kiyoonkim/aag
# Pipeline Tag: None
# Tags: ['transformers', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: danielsteinigen/GenerAd-AI
# Model Name: danielsteinigen/GenerAd-AI
# Pipeline Tag: text-generation
# Tags: ['adapter-transformers', 'text-generation', 'en', 'dataset:multi_woz_v22', 'license:openrail', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnext101_64x4d.gluon_in1k
# Model Name: timm/seresnext101_64x4d.gluon_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1709.01507', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: yilin1344/GenerOasisLyricsOne-AI
# Model Name: yilin1344/GenerOasisLyricsOne-AI
# Pipeline Tag: None
# Tags: ['transformers', 'en', 'license:openrail', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnext101d_32x8d.ah_in1k
# Model Name: timm/seresnext101d_32x8d.ah_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1611.05431', 'arxiv:1512.03385', 'arxiv:1709.01507', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: dvruette/llama-13b-pretrained-dropout
# Model Name: dvruette/llama-13b-pretrained-dropout
# Pipeline Tag: text-generation
# Tags: ['transformers', 'pytorch', 'llama', 'text-generation', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnextaa101d_32x8d.ah_in1k
# Model Name: timm/seresnextaa101d_32x8d.ah_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:2110.00476', 'arxiv:1611.05431', 'arxiv:1904.11486', 'arxiv:1512.03385', 'arxiv:1709.01507', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: joepdekraker/testchatbot
# Model Name: joepdekraker/testchatbot
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: drbeane/LunarLander-v2-ppo
# Model Name: drbeane/LunarLander-v2-ppo
# Pipeline Tag: reinforcement-learning
# Tags: ['stable-baselines3', 'LunarLander-v2', 'deep-reinforcement-learning', 'reinforcement-learning', 'model-index', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnextaa101d_32x8d.sw_in12k
# Model Name: timm/seresnextaa101d_32x8d.sw_in12k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1904.11486', 'arxiv:1512.03385', 'arxiv:1709.01507', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Francisco828/Girls
# Model Name: Francisco828/Girls
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: timm/seresnextaa101d_32x8d.sw_in12k_ft_in1k
# Model Name: timm/seresnextaa101d_32x8d.sw_in12k_ft_in1k
# Pipeline Tag: image-classification
# Tags: ['timm', 'pytorch', 'safetensors', 'image-classification', 'arxiv:1611.05431', 'arxiv:1904.11486', 'arxiv:1512.03385', 'arxiv:1709.01507', 'arxiv:1812.01187', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: shm0007/terminal-test
# Model Name: shm0007/terminal-test
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: GreatBaba/gpt2-wikitext2
# Model Name: GreatBaba/gpt2-wikitext2
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: zzztuizz/ctuz
# Model Name: zzztuizz/ctuz
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: SaathvikD/dqn-BreakoutNoFrameskip-v4
# Model Name: SaathvikD/dqn-BreakoutNoFrameskip-v4
# Pipeline Tag: reinforcement-learning
# Tags: ['stable-baselines3', 'BreakoutNoFrameskip-v4', 'deep-reinforcement-learning', 'reinforcement-learning', 'model-index', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: evadraganova/GenerAd-AI
# Model Name: evadraganova/GenerAd-AI
# Pipeline Tag: None
# Tags: ['license:mit', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: omansh22/audit-trail
# Model Name: omansh22/audit-trail
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: sandeepvarma99/tacl-bert-base-uncased-finetuned-squad-finetuned-squad-1
# Model Name: sandeepvarma99/tacl-bert-base-uncased-finetuned-squad-finetuned-squad-1
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: andreaRapuzzi/GenerAd-AI
# Model Name: andreaRapuzzi/GenerAd-AI
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: eddiekirkland/gptj8bit
# Model Name: eddiekirkland/gptj8bit
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: RomanTeucher/PythonCoder
# Model Name: RomanTeucher/PythonCoder
# Pipeline Tag: text-generation
# ...
# --------------------------------------------------------------------------------
# Model ID: joseph-supples/q-FrozenLake-v1-4x4-noSlippery
# Model Name: joseph-supples/q-FrozenLake-v1-4x4-noSlippery
# Pipeline Tag: reinforcement-learning
# Tags: ['FrozenLake-v1-4x4-no_slippery', 'q-learning', 'reinforcement-learning', 'custom-implementation', 'model-index', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: ccoke/yrial
# Model Name: ccoke/yrial
# Pipeline Tag: None
# Tags: ['license:unknown', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: hfl/chinese-alpaca-lora-13b
# Model Name: hfl/chinese-alpaca-lora-13b
# Pipeline Tag: None
# Tags: ['zh', 'license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: joseph-supples/taxiv3-QTable
# Model Name: joseph-supples/taxiv3-QTable
# Pipeline Tag: reinforcement-learning
# Tags: ['Taxi-v3', 'q-learning', 'reinforcement-learning', 'custom-implementation', 'model-index', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Traummacher/embed
# Model Name: Traummacher/embed
# Pipeline Tag: None
# Tags: ['license:openrail', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Traummacher/lora
# Model Name: Traummacher/lora
# Pipeline Tag: None
# Tags: ['license:openrail', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: mikephillips/slant-all-lora-2-1-2
# Model Name: mikephillips/slant-all-lora-2-1-2
# Pipeline Tag: text-to-image
# Tags: ['diffusers', 'stable-diffusion', 'stable-diffusion-diffusers', 'text-to-image', 'lora', 'base_model:stabilityai/stable-diffusion-2-1-base', 'base_model:adapter:stabilityai/stable-diffusion-2-1-base', 'license:creativeml-openrail-m', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: hanifnoerr/Fine-tuned-Indonesian-Sentiment-Classifier
# Model Name: hanifnoerr/Fine-tuned-Indonesian-Sentiment-Classifier
# Pipeline Tag: text-classification
# Tags: ['transformers', 'pytorch', 'tensorboard', 'bert', 'text-classification', 'generated_from_trainer', 'id', 'dataset:indonlu', 'license:mit', 'model-index', 'autotrain_compatible', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: rsigim/your-model-name
# Model Name: rsigim/your-model-name
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: Traummacher/model
# Model Name: Traummacher/model
# Pipeline Tag: None
# Tags: ['license:openrail', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: lierzhao/models
# Model Name: lierzhao/models
# Pipeline Tag: None
# Tags: ['license:mit', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Cohere/Command-nightly
# Model Name: Cohere/Command-nightly
# Pipeline Tag: None
# Tags: ['license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: KIRETOLEMON/kanpiromi
# Model Name: KIRETOLEMON/kanpiromi
# Pipeline Tag: None
# Tags: ['license:other', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: PatricioQ/Dioses
# Model Name: PatricioQ/Dioses
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: adabingw/lyrr
# Model Name: adabingw/lyrr
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: shanemarvinmay/my_awesome_opus_books_model
# Model Name: shanemarvinmay/my_awesome_opus_books_model
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: gorborukov/koala-7b-ggml-q4_0
# Model Name: gorborukov/koala-7b-ggml-q4_0
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: zhaoxvdong/my_model
# Model Name: zhaoxvdong/my_model
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: Zolyer/ja-t5-base-summary
# Model Name: Zolyer/ja-t5-base-summary
# Pipeline Tag: text2text-generation
# Tags: ['transformers', 'pytorch', 't5', 'text2text-generation', 'generated_from_trainer', 'license:cc-by-sa-4.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: LIS-TEN/yanwu
# Model Name: LIS-TEN/yanwu
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: Kelvinwy53/Senyamikulora
# Model Name: Kelvinwy53/Senyamikulora
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: rithwik-db/embedded-e5-large-500
# Model Name: rithwik-db/embedded-e5-large-500
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: rithwik-db/embedded-e5-large-500-correct
# Model Name: rithwik-db/embedded-e5-large-500-correct
# Pipeline Tag: sentence-similarity
# Tags: ['sentence-transformers', 'pytorch', 'bert', 'feature-extraction', 'sentence-similarity', 'transformers', 'autotrain_compatible', 'text-embeddings-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Fred99774/horusork
# Model Name: Fred99774/horusork
# Pipeline Tag: text-to-image
# Tags: ['diffusers', 'safetensors', 'text-to-image', 'stable-diffusion', 'license:creativeml-openrail-m', 'autotrain_compatible', 'endpoints_compatible', 'diffusers:StableDiffusionPipeline', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: GreeneryScenery/SheepsControlV3
# Model Name: GreeneryScenery/SheepsControlV3
# Pipeline Tag: image-to-image
# Tags: ['diffusers', 'art', 'ControlNet', 'image-to-image', 'dataset:GreeneryScenery/SheepsNetV2', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: nolanaatama/srblrchv
# Model Name: nolanaatama/srblrchv
# Pipeline Tag: None
# Tags: ['license:creativeml-openrail-m', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: jiuyiyuyi/esm2_t12_35M_UR50D-Fluorescence-230407
# Model Name: jiuyiyuyi/esm2_t12_35M_UR50D-Fluorescence-230407
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: xiexueyan/testModel
# Model Name: xiexueyan/testModel
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: mdfrearth/data
# Model Name: mdfrearth/data
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: Mihara-bot/BART-BASE-CHINESE-V2
# Model Name: Mihara-bot/BART-BASE-CHINESE-V2
# Pipeline Tag: text2text-generation
# Tags: ['transformers', 'pytorch', 'bart', 'text2text-generation', 'license:apache-2.0', 'autotrain_compatible', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: testing445/b
# Model Name: testing445/b
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: Colifero/biggie
# Model Name: Colifero/biggie
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: rithwik-db/bert-base-cased-10
# Model Name: rithwik-db/bert-base-cased-10
# Pipeline Tag: sentence-similarity
# Tags: ['sentence-transformers', 'pytorch', 'bert', 'feature-extraction', 'sentence-similarity', 'transformers', 'autotrain_compatible', 'text-embeddings-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: dkincaid/t5-small-finetuned-xsum
# Model Name: dkincaid/t5-small-finetuned-xsum
# Pipeline Tag: text2text-generation
# Tags: ['transformers', 'pytorch', 'tensorboard', 't5', 'text2text-generation', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: AndrewMetaBlock/AndrewTest
# Model Name: AndrewMetaBlock/AndrewTest
# Pipeline Tag: None
# Tags: ['license:apache-2.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: john1786/V08_V08
# Model Name: john1786/V08_V08
# Pipeline Tag: None
# Tags: ['license:unknown', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Drararara/llama-13B-ggml
# Model Name: Drararara/llama-13B-ggml
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: rithwik-db/bert-base-cased-101
# Model Name: rithwik-db/bert-base-cased-101
# Pipeline Tag: sentence-similarity
# Tags: ['sentence-transformers', 'pytorch', 'bert', 'feature-extraction', 'sentence-similarity', 'transformers', 'autotrain_compatible', 'text-embeddings-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: 11syx/lora_sks_xiaoxin
# Model Name: 11syx/lora_sks_xiaoxin
# Pipeline Tag: text-to-image
# Tags: ['paddlepaddle', 'stable-diffusion', 'stable-diffusion-ppdiffusers', 'text-to-image', 'ppdiffusers', 'lora', 'base_model:runwayml/stable-diffusion-v1-5', 'base_model:adapter:runwayml/stable-diffusion-v1-5', 'license:creativeml-openrail-m', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: rithwik-db/bert-base-cased-10-301cf9
# Model Name: rithwik-db/bert-base-cased-10-301cf9
# Pipeline Tag: sentence-similarity
# Tags: ['sentence-transformers', 'pytorch', 'bert', 'feature-extraction', 'sentence-similarity', 'transformers', 'autotrain_compatible', 'text-embeddings-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Corianas/Quokka_1.3b
# Model Name: Corianas/Quokka_1.3b
# Pipeline Tag: text-generation
# Tags: ['transformers', 'pytorch', 'tensorboard', 'safetensors', 'gpt2', 'text-generation', 'en', 'dataset:the_pile', 'dataset:guanaco/guanaco', 'arxiv:1910.09700', 'license:apache-2.0', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: sumitori/meme
# Model Name: sumitori/meme
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: adahms/my_awesome_billsum_model
# Model Name: adahms/my_awesome_billsum_model
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: raven316/pokemon-lora
# Model Name: raven316/pokemon-lora
# Pipeline Tag: text-to-image
# Tags: ['diffusers', 'stable-diffusion', 'stable-diffusion-diffusers', 'text-to-image', 'lora', 'license:creativeml-openrail-m', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: HenryJJ/vincua-13b
# Model Name: HenryJJ/vincua-13b
# Pipeline Tag: text-generation
# Tags: ['transformers', 'pytorch', 'llama', 'text-generation', 'vicuna', 'text-generation-inference', 'autotrain_compatible', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: beverlyjfu/ProtGPT2-finetuned-localization
# Model Name: beverlyjfu/ProtGPT2-finetuned-localization
# Pipeline Tag: text-classification
# Tags: ['transformers', 'pytorch', 'tensorboard', 'gpt2', 'text-classification', 'autotrain_compatible', 'text-generation-inference', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Rorical/bloom-7b1-lightnovel-lora
# Model Name: Rorical/bloom-7b1-lightnovel-lora
# Pipeline Tag: text-generation
# Tags: ['peft', 'bloom', 'text-generation', 'zh', 'license:bigscience-bloom-rail-1.0', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: Jamin20/whisper-fine-tuned_de_arg_new
# Model Name: Jamin20/whisper-fine-tuned_de_arg_new
# Pipeline Tag: automatic-speech-recognition
# Tags: ['transformers', 'pytorch', 'tensorboard', 'whisper', 'automatic-speech-recognition', 'hf-asr-leaderboard', 'generated_from_trainer', 'de', 'dataset:mozilla-foundation/common_voice_11_0', 'license:apache-2.0', 'model-index', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: justinsiow/ppo-Huggy
# Model Name: justinsiow/ppo-Huggy
# Pipeline Tag: reinforcement-learning
# Tags: ['ml-agents', 'tensorboard', 'onnx', 'Huggy', 'deep-reinforcement-learning', 'reinforcement-learning', 'ML-Agents-Huggy', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: TariqJamil/vit-base-patch16-224-in21k-handsActDetect
# Model Name: TariqJamil/vit-base-patch16-224-in21k-handsActDetect
# Pipeline Tag: image-classification
# Tags: ['transformers', 'tf', 'tensorboard', 'vit', 'image-classification', 'generated_from_keras_callback', 'license:apache-2.0', 'autotrain_compatible', 'endpoints_compatible', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: YueMafighting/FollowYourPose_v1
# Model Name: YueMafighting/FollowYourPose_v1
# Pipeline Tag: None
# Tags: ['diffusers', 'region:us']
# --------------------------------------------------------------------------------
# Model ID: wangyujing1234/gpt-neo-125M-imdb-lora
# Model Name: wangyujing1234/gpt-neo-125M-imdb-lora
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: drkmr/distilbert-base-uncased-kmr-finetuned-emotion-2
# Model Name: drkmr/distilbert-base-uncased-kmr-finetuned-emotion-2
# Pipeline Tag: None
# Tags: ['region:us']
# --------------------------------------------------------------------------------
# Model ID: vocabtrimmer/mbart-large-cc25-trimmed-it-itquad-qa
# Model Name: vocabtrimmer/mbart-large-cc25-trimmed-it-itquad-qa
# Pipeline Tag: text2text-generation
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b3e82471eea8> in <cell line: 10>()
#      12     print(f"Model Name: {model.modelId}")
#      13     print(f"Pipeline Tag: {model.pipeline_tag}")
# ---> 14     print(f"Tags: {model.tags}")
#      15     print("-" * 80)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     398                 string = string.decode(self.encoding, 'replace')
#     399
# --> 400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
#     402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in _is_master_process(self)
#     307
#     308     def _is_master_process(self):
# --> 309         return os.getpid() == self._master_pid
#     310
#     311     def set_parent(self, parent):
#
# KeyboardInterrupt:
