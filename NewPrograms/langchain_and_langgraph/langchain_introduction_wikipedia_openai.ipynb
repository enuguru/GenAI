# %%
# !pip install langchain langchain-openai langchain-community wikipedia

# %%
import os
from langchain_openai import ChatOpenAI
from langchain_community.utilities import WikipediaAPIWrapper
from langchain_community.tools import WikipediaQueryRun

# %%
#import openai
#from openai import OpenAI
from google.colab import userdata
openai_api_key = userdata.get("OPENAI_API_KEY")
#api_key = ""

# %%
# Set your OpenAI API key
#os.environ["OPENAI_API_KEY"] = "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"

# Create LLM
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)

# Create Wikipedia tool
wiki = WikipediaQueryRun(api_wrapper=WikipediaAPIWrapper())

# %%
# Ask user query
query = input("Ask a question: ")

# Search Wikipedia
wiki_result = wiki.run(query)
print("\nWikipedia Result:")
print(wiki_result)

# Ask LLM to summarize answer
prompt = f"""
Answer the question using the information from Wikipedia.

Question: {query}

Wikipedia Information:
{wiki_result}

Give a clear answer.
"""
# Out:
# Ask a question: Who is Sachin Tendulkar
#
# Wikipedia Result:
# Page: Arjun Tendulkar
# Summary: Arjun Sachin Tendulkar  (born 24 September 1999) is an Indian cricketer who plays for Goa in domestic cricket and Lucknow Super Giants in the Indian Premier League. He is the son of former cricketer Sachin Tendulkar.
#
#
#
# Page: Sachin Tendulkar
# Summary: Sachin Ramesh Tendulkar ( ; Marathi: [sətɕin t̪eɳɖulkəɾ]; born 24 April 1973) is an Indian former international cricketer who captained the Indian national team. Often dubbed the "God of Cricket" in India, he is widely regarded as one of the greatest cricketers of all time. He holds several world records, including being the all-time highest run-scorer in international cricket, receiving the most player of the match awards in international cricket, and being the only batsman to score 100 international centuries. Tendulkar was a Member of Parliament, Rajya Sabha by presidential nomination from 2012 to 2018.
# ...

# %%
response = llm.invoke(prompt)

print("\nAnswer:")
print(response.content)
# Out:
# Answer:
# Sachin Tendulkar is an Indian former international cricketer, widely regarded as one of the greatest cricketers of all time. Born on April 24, 1973, he captained the Indian national team and is often referred to as the "God of Cricket" in India. Tendulkar holds numerous world records, including being the all-time highest run-scorer in international cricket and the only batsman to score 100 international centuries. He played for over 24 years, making his Test debut at the age of 16 and retiring in 2013 after his 200th Test match. He has received several prestigious awards, including the Bharat Ratna, India's highest civilian award, and was inducted into the ICC Cricket Hall of Fame in 2019.
