# %%
# !pip install langchain langchain-community langchain-google-genai faiss-cpu sentence-transformers

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate

# %%
# ----------------------------
# API Key
# ----------------------------

#os.environ["GOOGLE_API_KEY"] = "YOUR_API_KEY"
import os
from google.colab import userdata
from google import genai
# Load API key from Colab Secrets into environment variable
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")

# %%
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

prompt = ChatPromptTemplate.from_template("""
Generate 3 different search queries for the question.

Question: {question}
""")

chain = prompt | llm

question = "Which company invented hybrid cars?"

result = chain.invoke({"question": question})

print(result.content)
# Out:
# Here are 3 different search queries for the question "Which company invented hybrid cars?":
#
# 1.  **Company that invented hybrid cars**
# 2.  **First company to produce a hybrid car**
# 3.  **Who developed the first hybrid car?**
