# %%
# ============================================================
# LEVEL 1: SIMPLE LLM-ONLY APPLICATION
# Gemini + Python
# No RAG
# No Vector Database
# No External Tools
# ============================================================

# !pip install -q google-genai

from google import genai
from google.colab import userdata

# %%
# ------------------------------------------------------------
# 1. Read Gemini API key from Colab Secrets
# ------------------------------------------------------------

import os
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_API_KEY")
client = genai.Client(api_key=api_key)
os.environ["GOOGLE_API_KEY"] = api_key
#import os
#from getpass import getpass

#os.environ["GOOGLE_API_KEY"] = getpass("Enter Gemini API key: ")

# %%
# ------------------------------------------------------------
# 2. Ask user a question
# ------------------------------------------------------------

question = input("Enter your question: ")

# ------------------------------------------------------------
# 3. Send question directly to Gemini
# ------------------------------------------------------------

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=question
)

# ------------------------------------------------------------
# 4. Display answer
# ------------------------------------------------------------

print("\nGemini Answer:")
print("=" * 50)
print(response.text)
# Out:
# Enter your question: Who is Harbhajan Singh?
#
# Gemini Answer:
# ==================================================
# **Harbhajan Singh**, often affectionately known as **'Bhajji'** or **'The Turbanator'**, is a former **Indian international cricketer** and one of the most successful **off-spin bowlers** the country has ever produced.
#
# Here's a breakdown of who he is:
#
# 1.  **Cricketer:** He represented India in all three formats of the game (Tests, One Day Internationals, and Twenty20 Internationals) for over two decades, making his debut in 1998.
# 2.  **Off-Spin Bowler:** He was renowned for his aggressive bowling style, sharp turn, and deceptive variations, including the 'doosra' (a delivery that turns away from the right-handed batsman).
# 3.  **Key Achievements & Milestones:**
#     *   He was the **first Indian bowler to take a Test hat-trick**, achieved against Australia in the historic Kolkata Test of 2001.
#     *   He finished his Test career with **417 wickets** and his ODI career with **269 wickets**, placing him among India's leading wicket-takers in both formats.
#     *   He was a crucial member of the Indian teams that won the **2007 ICC World Twenty20** and the **2011 ICC Cricket World Cup**.
#     *   He formed a formidable spin partnership with Anil Kumble for many years in Test cricket.
# 4.  **IPL Star:** Beyond international cricket, Harbhajan was a prominent figure in the Indian Premier League (IPL), representing teams like Mumbai Indians and Chennai Super Kings. He won multiple IPL titles with both franchises.
# 5.  **Post-Retirement Roles:** After retiring from all forms of cricket in December 2021, Harbhajan has transitioned into:
#     *   **Cricket Commentator and Expert:** He is frequently seen on various media platforms sharing his insights on the game.
#     *   **Politician:** More recently, he entered politics and was elected as a Member of Parliament (Rajya Sabha) for the Aam Aadmi Party (AAP) in March 2022.
#
# Harbhajan Singh's career was marked by his passionate personality, competitive spirit, and ability to deliver under pressure. He left an indelible mark on Indian cricket with his unique bowling style and fiery on-field presence.
