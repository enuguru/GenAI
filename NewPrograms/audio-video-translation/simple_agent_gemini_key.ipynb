# %%
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_API_KEY")
client = genai.Client(api_key=api_key)

# %%
#client = genai.Client(api_key=API_KEY)

# Create a chat session
chat = client.chats.create(
    model="gemini-2.5-flash"
)

print("Agent started. Type 'exit' to quit.\n")

while True:
    user_input = input("You: ")

    if user_input.lower() in ["exit", "quit"]:
        print("Goodbye!")
        break

    try:
        response = chat.send_message(user_input)

        print("\nAgent:")
        print(response.text)
        print()

    except Exception as e:
        print(f"Error: {e}")
# Out:
# Agent started. Type 'exit' to quit.
#
# You: Who is Christiano Ronaldo
#
# Agent:
# **Cristiano Ronaldo dos Santos Aveiro** (born February 5, 1985) is a Portuguese professional footballer who is widely regarded as one of the greatest players of all time.
#
# Here are some key facts about him:
#
# 1.  **Position:** Primarily plays as a forward (striker or winger).
# 2.  **Nationality:** Portuguese. He is the captain of the Portugal national team.
# 3.  **Career Highlights (Clubs):**
#     *   **Sporting CP (Portugal):** Where he began his professional career.
#     *   **Manchester United (England):** Achieved global fame and won his first UEFA Champions League title and Ballon d'Or.
#     *   **Real Madrid (Spain):** Where he spent the peak of his career, becoming the club's all-time leading goalscorer and winning four more Champions League titles and multiple Ballon d'Or awards.
#     *   **Juventus (Italy):** Continued his goal-scoring prowess, winning multiple Serie A titles.
#     *   **Al Nassr (Saudi Arabia):** His current club, having moved there in early 2023.
# 4.  **International Career:**
#     *   He is the **all-time leading male international goalscorer** in football history.
#     *   He is also the most-capped male player in international football.
#     *   He captained Portugal to victory in the **UEFA European Championship (Euro 2016)** and the **UEFA Nations League (2019)**.
# 5.  **Individual Awards:**
#     *   He has won the **Ballon d'Or** (awarded to the world's best player) five times.
#     *   Numerous Golden Boot awards for being the top scorer in various leagues and competitions (e.g., Champions League, Premier League, La Liga, Serie A).
# 6.  **Playing Style:** Known for his incredible athleticism, speed, powerful shooting, exceptional heading ability, and prolific goal-scoring record. He is also famous for his relentless work ethic and dedication.
# 7.  **Global Icon:** Beyond football, Ronaldo is a global cultural icon, entrepreneur, and one of the most followed individuals on social media platforms.
#
# In essence, Cristiano Ronaldo is a legendary figure in football, celebrated for his extraordinary talent, unparalleled goal-scoring ability, and numerous achievements at both club and international levels.
#
# You: What did i ask earlier?
#
# Agent:
# You asked:
#
# **"Who is Christiano Ronaldo"**
#
# You: who is Christiano Ronaldo, give the answer in 10 words
#
# Agent:
# Legendary Portuguese footballer, five-time Ballon d'Or winner, record-breaking goalscorer.
