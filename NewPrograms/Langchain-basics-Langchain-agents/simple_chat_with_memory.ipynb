# %%
from datetime import datetime

# %%
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_API_KEY")
client = genai.Client(api_key=api_key)

# %%
chat = client.chats.create(
    model="gemini-2.5-flash"
)

system_prompt = """
You are a helpful AI assistant.
Answer in simple English.
Be concise and accurate.
"""

chat.send_message(system_prompt)

print("AI Agent Ready (type exit to quit)\n")

while True:

    query = input("You: ")

    if query.lower() == "exit":
        break

    response = chat.send_message(query)

    print("\nAgent:", response.text)
    print()
# Out:
# AI Agent Ready (type exit to quit)
#
# You: time
#
# Agent: Time is how we measure events and how long they last. It always moves forward.
#
# You: what did i ask earlier
#
# Agent: You asked, "time".
#
# You: exit
