# %%
# !pip install -U langchain langchain-google-genai
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (1.3.6)
# Collecting langchain
#   Downloading langchain-1.3.10-py3-none-any.whl.metadata (6.0 kB)
# Collecting langchain-google-genai
#   Downloading langchain_google_genai-4.2.5-py3-none-any.whl.metadata (2.7 kB)
# Collecting langchain-core<2.0.0,>=1.4.7 (from langchain)
#   Downloading langchain_core-1.4.8-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph<1.3.0,>=1.2.5 (from langchain)
#   Downloading langgraph-1.2.6-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.12.3)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (1.68.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.47.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (1.33)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.4.7->langchain)
#   Downloading langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.8.12)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain) (0.16.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.3.0,>=1.2.5->langchain) (3.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.3)
# Downloading langchain-1.3.10-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.0/133.0 kB 1.4 MB/s eta 0:00:00
# Downloading langchain_google_genai-4.2.5-py3-none-any.whl (69 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 4.5 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading langchain_core-1.4.8-py3-none-any.whl (557 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.4/557.4 kB 5.8 MB/s eta 0:00:00
# Downloading langgraph-1.2.6-py3-none-any.whl (246 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.1/246.1 kB 17.9 MB/s eta 0:00:00
# Downloading langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Installing collected packages: filetype, langchain-protocol, langchain-core, langchain-google-genai, langgraph, langchain
#   Attempting uninstall: langchain-protocol
#     Found existing installation: langchain-protocol 0.0.16
#     Uninstalling langchain-protocol-0.0.16:
#       Successfully uninstalled langchain-protocol-0.0.16
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.3
#     Uninstalling langchain-core-1.4.3:
#       Successfully uninstalled langchain-core-1.4.3
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.2.4
#     Uninstalling langgraph-1.2.4:
#       Successfully uninstalled langgraph-1.2.4
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.6
#     Uninstalling langchain-1.3.6:
#       Successfully uninstalled langchain-1.3.6
# Successfully installed filetype-1.2.0 langchain-1.3.10 langchain-core-1.4.8 langchain-google-genai-4.2.5 langchain-protocol-0.0.18 langgraph-1.2.6

# %%
import os
from google import genai
from google.colab import userdata

#API_KEY = put the new api key here created latest
api_key = userdata.get("GOOGLE_API_KEY")
client = genai.Client(api_key=api_key)
os.environ["GOOGLE_API_KEY"] = api_key

# %%
import os

from langchain_google_genai import ChatGoogleGenerativeAI

# Gemini API Key
#os.environ["GOOGLE_API_KEY"] = "YOUR_GEMINI_API_KEY"

# Create LLM
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# Ask a question
response = llm.invoke(
    "Explain Machine Learning in simple English."
)

print(response.content)
# Out:
# Imagine you want to teach a computer to tell the difference between a picture of a **cat** and a picture of a **dog**.
#
# **The Old Way (without Machine Learning):**
# You'd have to write down *every single rule* the computer needs to follow: "If it has pointed ears and whiskers, it's a cat. If it has floppy ears and a long snout, it's a dog. But wait, some cats have floppy ears! And some dogs have pointed ears! What about the tail? What about the fur color?" This quickly gets incredibly complicated and impossible for humans to list every possibility.
#
# **The Machine Learning Way:**
# Instead of writing all those rules, you do this:
#
# 1.  **Gather Data:** You show the computer thousands of pictures, some clearly labeled "cat" and others labeled "dog."
# 2.  **Let it Learn:** You tell the computer to look at all these pictures and try to figure out what patterns or features generally belong to cats, and what belongs to dogs. It's like a child learning – you show them many examples, and they start to pick up on the common characteristics themselves.
# 3.  **Make Predictions:** Once the computer has "learned" from all that data, you can show it a *new* picture it has never seen before. Based on the patterns it identified, it will then make an "intelligent guess" and tell you, "I think this is a cat!" or "I think this is a dog!"
#
# **So, in simple terms:**
#
# Machine Learning is about **teaching computers to learn from experience (data)**, rather than being explicitly told every single step.
#
# It's like giving computers a brain that gets smarter with more information, allowing them to:
# *   **Recognize patterns**
# *   **Make predictions**
# *   **Make decisions**
#
# **Examples you use every day:**
#
# *   **Netflix/Spotify suggestions:** Learning what movies or songs you like.
# *   **Spam filters:** Learning what emails are junk.
# *   **Voice assistants (Siri/Alexa):** Learning to understand your words.
# *   **Face unlock on your phone:** Learning your face.
# *   **Online shopping recommendations:** Learning what products you might want.
#
# It's about computers getting better at a task the more data and "practice" they get!

# %%
#import os

from langchain_core.prompts import ChatPromptTemplate
from langchain_google_genai import ChatGoogleGenerativeAI

#os.environ["GOOGLE_API_KEY"] = "YOUR_GEMINI_API_KEY"

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

prompt = ChatPromptTemplate.from_template(
    """
    Explain the topic '{topic}'
    to a beginner in simple English.
    """
)

chain = prompt | llm

response = chain.invoke(
    {"topic": "Neural Networks"}
)

print(response.content)
# Out:
# Imagine you have a toddler who is learning to recognize different animals. You show them a picture of a cat and say "cat." Then a dog and say "dog." Slowly, over time, they start to pick up on the features: pointy ears, whiskers, fluffy tail for a cat; floppy ears, wet nose, wagging tail for a dog. Even if they see a cat they've never seen before, they can usually tell it's a cat.
#
# **A Neural Network is a computer program inspired by how our brains work, especially how we learn from experience.**
#
# Let's break it down simply:
#
# ---
#
# ### The Super Simple Explanation:
#
# A Neural Network is like a "smart learning system" for computers. Instead of you writing down every single rule ("if it has whiskers AND pointy ears AND a fluffy tail, it's a cat"), you show it a lot of examples, and it figures out the rules itself.
#
# ---
#
# ### How it Works (The Building Blocks):
#
# 1.  **Neurons (or Nodes): The Little Thinkers**
#     *   Imagine tiny light bulbs in a grid. Each bulb is a "neuron."
#     *   Each neuron takes some input, does a little calculation, and then decides whether to "light up" (activate) or not, passing its signal to the next bulbs.
#
# 2.  **Layers: The Assembly Line**
#     *   These neurons are organized into layers, like different stages in an assembly line:
#         *   **Input Layer:** This is where you feed in the raw information. If you're showing it a picture of a cat, the input layer might get information about each pixel's color and brightness.
#         *   **Hidden Layers:** This is where the magic happens! These layers are between the input and output. Neurons in these layers work together to find patterns. For our cat example, one hidden layer might detect edges, another might detect shapes like ears, and another might combine those to recognize a "cat face." You don't tell it *how* to find these patterns; it figures it out.
#         *   **Output Layer:** This is where the network gives its final answer. For our cat picture, the output layer might have two neurons: one that lights up if it thinks it's a "cat" and another for "not a cat" (or "dog," "bird," etc.).
#
# 3.  **Connections and Weights: The Strength of Relationships**
#     *   Every neuron in one layer is connected to neurons in the next layer, like wires.
#     *   Each connection has a "weight." Think of weights like volume knobs. If a connection has a high weight, it means that input is very important for the next neuron's decision. If it has a low weight, it's less important.
#     *   These weights are what the network "learns."
#
# ---
#
# ### How it Learns (The Training Process):
#
# This is the coolest part!
#
# 1.  **Show and Guess:** You show the network tons of examples (e.g., thousands of pictures labeled "cat" and thousands labeled "dog").
# 2.  **Initial Randomness:** At first, all the "volume knobs" (weights) are set randomly, so the network will make terrible guesses. It might say a cat is a dog.
# 3.  **Correction Time:** When it makes a wrong guess, you tell it, "No, that was a cat!" The network then slightly adjusts its "volume knobs" (weights) across all the connections to try and get closer to the right answer next time. This process is called **backpropagation** (don't worry about the fancy name, just know it's how it learns from mistakes).
# 4.  **Repeat, Repeat, Repeat:** You do this millions of times with countless examples. Each time it makes a mistake, it fine-tunes its internal connections.
# 5.  **Becoming an Expert:** Eventually, after seeing enough examples and getting enough corrections, the network becomes incredibly good at recognizing patterns. It learns to "see" what makes a cat a cat, even if it's a cat it's never seen before.
#
# ---
#
# ### Why are they so powerful?
#
# *   **Pattern Recognition:** They are brilliant at finding complex patterns in data that humans might miss or that are too complicated to write explicit rules for.
# *   **Adaptability:** They can learn and improve over time as they get more data.
# *   **No Explicit Rules:** You don't have to tell them *how* to do something, just give them examples, and they figure it out.
#
# ---
#
# ### Real-World Examples:
#
# *   **Image Recognition:** How your phone recognizes faces in photos, or how self-driving cars "see" pedestrians and other cars.
# *   **Voice Assistants:** How Siri, Alexa, or Google Assistant understand what you say.
# *   **Language Translation:** Translating text or speech from one language to another.
# *   **Recommendation Systems:** How Netflix suggests movies or Amazon suggests products you might like.
# *   **Medical Diagnosis:** Helping doctors analyze images (like X-rays) to find diseases.
#
# In essence, Neural Networks are powerful computational tools that mimic the learning ability of biological brains, allowing computers to learn from data and make intelligent decisions or predictions without being explicitly programmed for every possible scenario.

# %%
import os

from langchain_google_genai import ChatGoogleGenerativeAI

#os.environ["GOOGLE_API_KEY"] = "YOUR_GEMINI_API_KEY"

llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash"
)

while True:

    question = input("You: ")

    if question.lower() == "exit":
        break

    response = llm.invoke(question)

    print("\nAI:", response.content)
    print()
# Out:
# You: What is Langchain?
#
# AI: **LangChain** is an open-source framework designed to help developers build applications powered by Large Language Models (LLMs) more easily and effectively.
#
# Think of it as a toolkit or an "operating system" for LLMs. While LLMs like GPT-4, Llama, or Claude are incredibly powerful, they have limitations when used in isolation:
#
# 1.  **Lack of Memory:** They are stateless; each interaction is independent.
# 2.  **Lack of Real-time Information:** Their training data has a cut-off date.
# 3.  **Inability to Perform Actions:** They can't browse the internet, run code, or interact with APIs.
# 4.  **Difficulty with Complex Workflows:** Building multi-step reasoning processes is challenging.
#
# LangChain addresses these limitations by providing a set of tools and abstractions that allow LLMs to:
#
# *   **Connect to external data sources:** Retrieve relevant information from databases, documents, or the web.
# *   **Interact with external computational tools:** Use search engines, calculators, APIs, or even other LLMs.
# *   **Maintain conversational memory:** Remember previous interactions in a chat.
# *   **Orchestrate complex sequences of operations:** Chain together multiple LLM calls and tool uses to achieve a larger goal.
#
# ---
#
# ### Key Concepts and Components of LangChain:
#
# LangChain is built around several core modules:
#
# 1.  **Models (LLMs, ChatModels, Embeddings):** LangChain provides a standardized interface to interact with various LLM providers (OpenAI, Hugging Face, Anthropic, Google, etc.) and different types of models (text generation, chat, embeddings).
#
# 2.  **Prompts:** Tools for constructing, managing, and optimizing prompts for LLMs, including prompt templates for dynamic input and output parsers for structured responses.
#
# 3.  **Chains:** These are sequences of calls, which can involve LLMs, other chains, or utilities. They allow you to define a specific workflow. For example, a chain might take user input, pass it to an LLM, and then take the LLM's output and pass it to another component.
#
# 4.  **Retrieval:** This module focuses on fetching relevant data to augment the LLM's knowledge. A very common pattern is **Retrieval Augmented Generation (RAG)**, where LangChain helps:
#     *   Load documents (PDFs, text files, web pages).
#     *   Split them into chunks.
#     *   Embed them into vector stores.
#     *   Retrieve the most relevant chunks based on a query.
#     *   Pass those chunks to the LLM as context.
#
# 5.  **Agents:** This is one of the most powerful features. Agents allow an LLM to "reason" about what actions to take and what tools to use to achieve a goal. The LLM acts as a controller, deciding:
#     *   What is the user asking?
#     *   What tools do I have available (e.g., search engine, calculator, API call)?
#     *   Which tool should I use now?
#     *   What's the next step based on the tool's output?
#     *   When am I done?
#
# 6.  **Memory:** Provides mechanisms for an LLM application to remember past interactions, crucial for building stateful chatbots or conversational agents.
#
# 7.  **Tools:** Functions that agents can use to interact with the outside world (e.g., `GoogleSearchAPI`, `Calculator`, custom APIs).
#
# ---
#
# ### Why is LangChain Useful?
#
# *   **Rapid Prototyping:** Quickly build complex LLM applications without reinventing the wheel.
# *   **Modularity:** Reusable components make development more organized and efficient.
# *   **Flexibility:** Works with a wide range of LLMs, data sources, and tools.
# *   **Orchestration:** Simplifies the management of multi-step processes involving LLMs and external resources.
# *   **Enables Advanced Capabilities:** Facilitates RAG, agentic behavior, and conversational memory, which are difficult to implement from scratch.
#
# ---
#
# ### Common Use Cases:
#
# *   **Question Answering over Custom Data:** Building chatbots that can answer questions based on your specific documents (e.g., company policies, product manuals).
# *   **Automated Research Assistants:** Agents that can search the web, summarize findings, and answer complex queries.
# *   **Chatbots with Memory and Tool Use:** More sophisticated conversational agents that can remember context and perform actions like booking appointments or retrieving real-time data.
# *   **Data Extraction and Summarization:** Processing large volumes of text to extract key information or generate concise summaries.
# *   **Code Generation and Explanation:** Tools that can generate code snippets or explain existing code.
#
# ---
#
# In essence, LangChain empowers developers to move beyond simple LLM prompts and build sophisticated, intelligent applications that can interact with the real world, remember context, and perform complex tasks autonomously.
#
# You: exit
