# %%
# !pip install --upgrade crewai langchain-google-genai
# Out:
# Requirement already satisfied: crewai in /usr/local/lib/python3.12/dist-packages (1.15.2)
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.12/dist-packages (4.2.7)
# Requirement already satisfied: aiofiles~=24.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (24.1.0)
# Requirement already satisfied: aiosqlite~=0.21.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.21.0)
# Requirement already satisfied: appdirs~=1.4.4 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.4.4)
# Requirement already satisfied: cel-python<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.5.0)
# Requirement already satisfied: chromadb~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.1)
# Requirement already satisfied: click<9,>=8.1.7 in /usr/local/lib/python3.12/dist-packages (from crewai) (8.4.2)
# Requirement already satisfied: crewai-cli==1.15.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.15.2)
# Requirement already satisfied: crewai-core==1.15.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.15.2)
# Requirement already satisfied: httpx~=0.28.1 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.28.1)
# Requirement already satisfied: instructor>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.15.4)
# Requirement already satisfied: json-repair~=0.25.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.25.3)
# Requirement already satisfied: json5~=0.10.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.10.0)
# Requirement already satisfied: jsonref~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.0)
# Requirement already satisfied: lancedb<0.30.1,>=0.29.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.30.0)
# Requirement already satisfied: mcp~=1.26.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.26.0)
# Requirement already satisfied: openai<3,>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.43.0)
# Requirement already satisfied: openpyxl~=3.1.5 in /usr/local/lib/python3.12/dist-packages (from crewai) (3.1.5)
# Requirement already satisfied: opentelemetry-api~=1.42.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http~=1.42.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk~=1.42.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.42.1)
# Requirement already satisfied: pdfplumber~=0.11.4 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.11.10)
# Requirement already satisfied: portalocker~=2.7.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.7.0)
# Requirement already satisfied: pydantic-settings<3,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.10.1)
# Requirement already satisfied: pydantic<2.13,>=2.11.9 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.12.5)
# Requirement already satisfied: pyjwt<3,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.13.0)
# Requirement already satisfied: python-dotenv<2,>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.2.2)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (6.0.3)
# Requirement already satisfied: regex~=2026.1.15 in /usr/local/lib/python3.12/dist-packages (from crewai) (2026.1.15)
# Requirement already satisfied: tokenizers<1,>=0.21 in /usr/local/lib/python3.12/dist-packages (from crewai) (0.22.2)
# Requirement already satisfied: tomli-w~=1.1.0 in /usr/local/lib/python3.12/dist-packages (from crewai) (1.1.0)
# Requirement already satisfied: tomli~=2.0.2 in /usr/local/lib/python3.12/dist-packages (from crewai) (2.0.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from crewai-cli==1.15.2->crewai) (2026.6.17)
# Requirement already satisfied: cryptography>=42.0 in /usr/local/lib/python3.12/dist-packages (from crewai-cli==1.15.2->crewai) (49.0.0)
# Requirement already satisfied: packaging>=23.0 in /usr/local/lib/python3.12/dist-packages (from crewai-cli==1.15.2->crewai) (26.2)
# Requirement already satisfied: rich>=13.7.1 in /usr/local/lib/python3.12/dist-packages (from crewai-cli==1.15.2->crewai) (14.3.4)
# Requirement already satisfied: textual>=7.5.0 in /usr/local/lib/python3.12/dist-packages (from crewai-cli==1.15.2->crewai) (8.2.8)
# Requirement already satisfied: uv~=0.11.6 in /usr/local/lib/python3.12/dist-packages (from crewai-cli==1.15.2->crewai) (0.11.28)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (2.10.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.7 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai) (1.4.8)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.12/dist-packages (from aiosqlite~=0.21.0->crewai) (4.15.0)
# Requirement already satisfied: google-re2>=1.1.20240702 in /usr/local/lib/python3.12/dist-packages (from cel-python<0.6,>=0.5.0->crewai) (1.1.20251105)
# Requirement already satisfied: jmespath>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from cel-python<0.6,>=0.5.0->crewai) (1.1.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from cel-python<0.6,>=0.5.0->crewai) (1.3.1)
# Requirement already satisfied: pendulum>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from cel-python<0.6,>=0.5.0->crewai) (3.2.0)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.5.0)
# Requirement already satisfied: pybase64>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.49.0)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (2.0.2)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.42.1)
# Requirement already satisfied: pypika>=0.48.9 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (4.67.3)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (1.81.1)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (36.0.3)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (9.1.4)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (3.11.9)
# Requirement already satisfied: jsonschema>=4.19.0 in /usr/local/lib/python3.12/dist-packages (from chromadb~=1.1.0->crewai) (4.26.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.14.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.49.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (2.32.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx~=0.28.1->crewai) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx~=0.28.1->crewai) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx~=0.28.1->crewai) (0.16.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (3.14.1)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (0.18.0)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (3.1.6)
# Requirement already satisfied: jiter<0.15,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (0.14.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from instructor>=1.3.3->crewai) (2.41.5)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from lancedb<0.30.1,>=0.29.2->crewai) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in /usr/local/lib/python3.12/dist-packages (from lancedb<0.30.1,>=0.29.2->crewai) (18.1.0)
# Requirement already satisfied: lance-namespace>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from lancedb<0.30.1,>=0.29.2->crewai) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (0.9.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (0.16.2)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.26.0->crewai) (0.4.3)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.26.0->crewai) (0.0.32)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.26.0->crewai) (3.4.5)
# Requirement already satisfied: starlette>=0.27 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.26.0->crewai) (1.3.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from mcp~=1.26.0->crewai) (0.4.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl~=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http~=1.42.0->crewai) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http~=1.42.0->crewai) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http~=1.42.0->crewai) (1.42.1)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-proto==1.42.1->opentelemetry-exporter-otlp-proto-http~=1.42.0->crewai) (5.29.6)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk~=1.42.0->crewai) (0.63b1)
# Requirement already satisfied: pdfminer.six==20260107 in /usr/local/lib/python3.12/dist-packages (from pdfplumber~=0.11.4->crewai) (20260107)
# Requirement already satisfied: Pillow>=12.2.0 in /usr/local/lib/python3.12/dist-packages (from pdfplumber~=0.11.4->crewai) (12.3.0)
# Requirement already satisfied: pypdfium2>=5.9.0 in /usr/local/lib/python3.12/dist-packages (from pdfplumber~=0.11.4->crewai) (5.11.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20260107->pdfplumber~=0.11.4->crewai) (3.4.7)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<2.13,>=2.11.9->crewai) (0.7.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers<1,>=0.21->crewai) (1.20.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.9.1->instructor>=1.3.3->crewai) (1.24.2)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.12/dist-packages (from build>=1.0.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=42.0->crewai-cli==1.15.2->crewai) (2.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (4.9.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1,>=0.21->crewai) (1.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (3.1.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.19.0->chromadb~=1.1.0->crewai) (2026.5.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (1.9.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (2.5.0)
# Requirement already satisfied: durationpy>=0.7 in /usr/local/lib/python3.12/dist-packages (from kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (0.10)
# Requirement already satisfied: lance-namespace-urllib3-client==0.9.0 in /usr/local/lib/python3.12/dist-packages (from lance-namespace>=0.3.2->lancedb<0.30.1,>=0.29.2->crewai) (0.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (3.7.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.7->langchain-google-genai) (0.25.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.14.1->chromadb~=1.1.0->crewai) (25.12.19)
# Requirement already satisfied: tzdata>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pendulum>=3.1.0->cel-python<0.6,>=0.5.0->crewai) (2026.2)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from posthog<6.0.0,>=2.4.0->chromadb~=1.1.0->crewai) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->crewai-cli==1.15.2->crewai) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.7.1->crewai-cli==1.15.2->crewai) (2.20.0)
# Requirement already satisfied: mdit-py-plugins in /usr/local/lib/python3.12/dist-packages (from textual>=7.5.0->crewai-cli==1.15.2->crewai) (0.6.1)
# Requirement already satisfied: platformdirs<5,>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from textual>=7.5.0->crewai-cli==1.15.2->crewai) (4.10.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.9.0->chromadb~=1.1.0->crewai) (0.0.4)
# Requirement already satisfied: httptools>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.8.0)
# Requirement already satisfied: uvloop>=0.15.1 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (0.22.1)
# Requirement already satisfied: watchfiles>=0.20 in /usr/local/lib/python3.12/dist-packages (from uvicorn[standard]>=0.18.3->chromadb~=1.1.0->crewai) (1.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=42.0->crewai-cli==1.15.2->crewai) (3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->crewai-cli==1.15.2->crewai) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py[linkify]>=2.1.0->textual>=7.5.0->crewai-cli==1.15.2->crewai) (2.1.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai) (0.6.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb~=1.1.0->crewai) (3.3.1)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.12/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.1.0->textual>=7.5.0->crewai-cli==1.15.2->crewai) (2.0.0)

# %%
from crewai import Agent, Task, Crew
import os

# %%
from crewai import LLM

# %%
from google.colab import userdata
# --------------------------------
# SET GEMINI API KEY
# --------------------------------
os.environ["GOOGLE_API_KEY"] = userdata.get("GOOGLE_API_KEY")
#YOUR_GOOGLE_API_KEY = "GOOGLE_API_KEY"

# %%
# --------------------------------
# GEMINI 2.5 FLASH MODEL
# --------------------------------
from langchain_google_genai import ChatGoogleGenerativeAI

#llm = ChatGoogleGenerativeAI(
#    model="gemini-2.5-flash",
#    temperature=0.3
#)

llm = LLM(
    model="gemini/gemini-2.5-flash",
    temperature=0.3,
    #api_key=userdata.get("GOOGLE_API_KEY")
)

# %%
# --------------------------------
# AGENTS
# --------------------------------

idea_generator = Agent(
    role="Startup Idea Generator",
    goal="Generate innovative AI startup ideas",
    backstory="You are a creative AI entrepreneur who spots business opportunities.",
    llm=llm,
    verbose=True
)

market_analyst = Agent(
    role="Market Analyst",
    goal="Evaluate startup ideas for feasibility and market demand",
    backstory="You analyze business ideas and assess their potential.",
    llm=llm,
    verbose=True
)

business_planner = Agent(
    role="Business Planner",
    goal="Create a simple execution plan for promising ideas",
    backstory="You convert ideas into practical action plans.",
    llm=llm,
    verbose=True
)

# %%
# --------------------------------
# TASKS
# --------------------------------

idea_task = Task(
    description="Generate one innovative AI startup idea in the healthcare domain.",
    expected_output="A clear startup idea with problem statement and proposed AI solution.",
    agent=idea_generator
)

analysis_task = Task(
    description="Evaluate the proposed startup idea for market demand, competition, and feasibility.",
    expected_output="A structured evaluation including strengths, risks, and opportunity score.",
    agent=market_analyst
)

plan_task = Task(
    description="Create a simple 5-step execution roadmap for launching this startup.",
    expected_output="A clear step-by-step execution plan.",
    agent=business_planner
)

# %%
from crewai import Process

# %%
# --------------------------------
# CREW
# --------------------------------

crew = Crew(
    agents=[idea_generator, market_analyst, business_planner],
    tasks=[idea_task, analysis_task, plan_task],
    process=Process.sequential,   # Important for teaching
    verbose=True
)

# %%
# --------------------------------
# EXECUTE
# --------------------------------

result = await crew.kickoff_async()
print("\n\n===== FINAL OUTPUT =====\n")
print(result)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: a0ec9c71-8675-4a0f-bb1e-73a3fd30baff                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Generate one innovative AI startup idea in the healthcare domain.                                        │
# │  ID: b7864226-94e0-4530-8fb5-01860f63da8c                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Startup Idea Generator                                                                                  │
# │                                                                                                                 │
# │  Task: Generate one innovative AI startup idea in the healthcare domain.                                        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Startup Idea Generator                                                                                  │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  **Startup Idea: "NeuroSense AI"**                                                                              │
# │                                                                                                                 │
# │  **Problem Statement:**                                                                                         │
# │  Neurodegenerative diseases like Alzheimer's, Parkinson's, and even early stages of certain mental health       │
# │  conditions often manifest with incredibly subtle, non-specific symptoms that are easily overlooked or          │
# │  misattributed for years. Patients, families, and even healthcare providers frequently miss these early         │
# │  indicators, leading to significant diagnostic delays. This lost time is critical, as early intervention is     │
# │  paramount for maximizing treatment efficacy, slowing disease progression, and improving long-term quality of   │
# │  life. Current diagnostic methods are largely reactive, waiting for overt symptoms to become undeniable, by     │
# │  which point significant neurological damage may have already occurred.                                         │
# │                                                                                                                 │
# │  **Proposed AI Solution:**                                                                                      │
# │  NeuroSense AI proposes a proactive, privacy-preserving AI platform that continuously monitors and analyzes an  │
# │  individual's "digital phenotype" to detect subtle, pre-symptomatic indicators of neurodegenerative and         │
# │  cognitive decline. The platform integrates and processes multi-modal, longitudinal data streams from:          │
# │                                                                                                                 │
# │  1.  **Wearable Devices:** Analyzing changes in sleep patterns (e.g., REM sleep behavior disorder as a          │
# │  Parkinson's precursor), activity levels, gait stability, tremor detection, and heart rate variability.         │
# │  2.  **Smartphone/Computer Interaction:** Monitoring subtle shifts in typing speed and accuracy, scrolling      │
# │  patterns, app usage frequency, voice characteristics during calls (e.g., changes in pitch, tone, speech rate,  │
# │  vocabulary complexity), and even GPS-based mobility patterns.                                                  │
# │  3.  **Smart Home Sensors (optional, with explicit consent):** Detecting changes in daily routines, movement    │
# │  patterns within the home, or increased fall risk.                                                              │
# │  4.  **EHR Data (with patient and provider consent):** Integrating historical lab results, medication changes,  │
# │  and past diagnoses to provide context and refine predictive models.                                            │
# │                                                                                                                 │
# │  Utilizing advanced deep learning, anomaly detection, and explainable AI algorithms, NeuroSense AI establishes  │
# │  a personalized baseline for each user. It then identifies statistically significant deviations or emerging     │
# │  patterns that, when combined, correlate with known early markers of cognitive decline, motor skill             │
# │  degradation, or mood disorders. The system would generate privacy-preserving, actionable alerts for            │
# │  designated healthcare providers, enabling earlier diagnostic workups and interventions, potentially years      │
# │  before traditional symptom-based diagnoses. This shifts the paradigm from reactive treatment to proactive,     │
# │  personalized prevention and management, offering a critical window for more effective care.                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Generate one innovative AI startup idea in the healthcare domain.                                        │
# │  Agent: Startup Idea Generator                                                                                  │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Evaluate the proposed startup idea for market demand, competition, and feasibility.                      │
# │  ID: e950b29d-48b2-49f6-af16-5835d4a2324f                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Analyst                                                                                          │
# │                                                                                                                 │
# │  Task: Evaluate the proposed startup idea for market demand, competition, and feasibility.                      │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Market Analyst                                                                                          │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  ## Startup Idea Evaluation: NeuroSense AI                                                                      │
# │                                                                                                                 │
# │  ### Strengths                                                                                                  │
# │                                                                                                                 │
# │  1.  **Addresses a Critical Unmet Need:** The problem statement accurately highlights the significant           │
# │  diagnostic delays and missed early intervention windows for neurodegenerative diseases. NeuroSense AI          │
# │  directly tackles this by aiming for proactive, pre-symptomatic detection, which is a monumental challenge      │
# │  with immense potential impact on patient outcomes and healthcare costs.                                        │
# │  2.  **Innovative Multi-Modal Data Integration:** The proposed solution's strength lies in its comprehensive    │
# │  "digital phenotype" approach, integrating diverse data streams from wearables, smartphones, smart home         │
# │  sensors, and EHRs. This multi-modal strategy offers a richer, more holistic view of an individual's health,    │
# │  potentially leading to higher accuracy and earlier detection than single-source solutions.                     │
# │  3.  **Continuous, Longitudinal Monitoring:** Unlike episodic clinical assessments, NeuroSense AI's continuous  │
# │  monitoring capability allows for the detection of subtle, gradual changes over extended periods. This is       │
# │  crucial for neurodegenerative conditions, which often manifest with slow, incremental shifts in behavior and   │
# │  physiology.                                                                                                    │
# │  4.  **Privacy-Preserving and Explainable AI Focus:** The explicit mention of "privacy-preserving" and          │
# │  "explainable AI" algorithms is a significant strength. These features are critical for building patient        │
# │  trust, ensuring regulatory compliance (e.g., HIPAA, GDPR), and facilitating clinical adoption by providing     │
# │  transparency to healthcare providers.                                                                          │
# │  5.  **Large and Growing Market Demand:** The global population is aging rapidly, leading to a continuous       │
# │  increase in the prevalence of neurodegenerative diseases. This creates a vast and expanding market for         │
# │  effective early detection and management solutions, appealing to patients, families, healthcare providers,     │
# │  and even pharmaceutical companies for clinical trial recruitment.                                              │
# │  6.  **Potential for Significant Impact:** Early detection can unlock a critical window for intervention,       │
# │  potentially slowing disease progression, maximizing treatment efficacy, improving quality of life, and         │
# │  significantly reducing the long-term burden on healthcare systems and caregivers. It also holds promise for    │
# │  accelerating research and drug development by identifying at-risk individuals earlier.                         │
# │                                                                                                                 │
# │  ### Risks                                                                                                      │
# │                                                                                                                 │
# │  1.  **Technical Complexity and Accuracy Challenges:**                                                          │
# │      *   **Data Heterogeneity & Integration:** Integrating and normalizing data from a multitude of disparate   │
# │  sources (various wearable brands, smartphone models, EHR systems) is an enormous technical undertaking.        │
# │  Ensuring data quality and consistency across these platforms will be a continuous challenge.                   │
# │      *   **Signal-to-Noise Ratio:** Distinguishing subtle, disease-related patterns from normal variations,     │
# │  lifestyle factors, temporary anomalies, or even device errors requires extremely sophisticated algorithms and  │
# │  massive, diverse, and well-labeled training datasets. The risk of false positives (causing patient anxiety     │
# │  and unnecessary tests) and false negatives (eroding trust and missing critical windows) is high.               │
# │      *   **Personalized Baseline Establishment:** Defining a robust "personalized baseline" for each user,      │
# │  accounting for individual variability, age, lifestyle, and pre-existing conditions, is complex and requires    │
# │  significant initial data collection before meaningful deviations can be identified.                            │
# │      *   **Explainable AI Implementation:** While a stated goal, truly explainable AI in a deep learning,       │
# │  multi-modal context is still an active research area. Delivering clinically actionable explanations that       │
# │  healthcare providers can trust and interpret effectively is difficult.                                         │
# │  2.  **Regulatory Hurdles and Clinical Validation:**                                                            │
# │      *   **Medical Device Classification:** Given its claims of detecting early indicators of medical           │
# │  conditions, NeuroSense AI will almost certainly be classified as a medical device (e.g., FDA Class II or III,  │
# │  CE Mark). This necessitates rigorous, time-consuming, and expensive clinical trials and validation studies to  │
# │  prove safety, efficacy, and accuracy, which is a major barrier to market entry.                                │
# │      *   **Data Privacy and Security Compliance:** Handling highly sensitive, continuous health data from       │
# │  multiple sources requires impeccable adherence to evolving global data privacy regulations (HIPAA, GDPR,       │
# │  etc.). Any breach or perceived misuse of data could be catastrophic for trust and adoption.                    │
# │  3.  **Clinical Adoption and Reimbursement:**                                                                   │
# │      *   **Provider Buy-in:** Healthcare providers will need compelling evidence of accuracy, reliability, and  │
# │  clinical utility to integrate NeuroSense AI into their diagnostic workflows. The system must be user-friendly  │
# │  and provide actionable insights without overwhelming clinicians.                                               │
# │      *   **Patient Acceptance:** While the need is high, patients may have reservations about continuous,       │
# │  intimate data sharing, even with privacy assurances. Building trust and demonstrating clear benefits will be   │
# │  crucial.                                                                                                       │
# │      *   **Reimbursement Models:** Establishing clear pathways for reimbursement from insurance providers for   │
# │  such a novel, proactive monitoring service will be critical for widespread adoption and financial viability.   │
# │  This can be a lengthy and complex process.                                                                     │
# │  4.  **Competition and Differentiation:**                                                                       │
# │      *   **Specialized Solutions:** While NeuroSense AI's multi-modal approach is a strength, many companies    │
# │  are developing highly specialized AI solutions for specific biomarkers or single data streams (e.g.,           │
# │  eye-tracking for Parkinson's, voice analysis for Alzheimer's). These might achieve faster regulatory approval  │
# │  and clinical validation for narrower use cases.                                                                │
# │      *   **Big Tech Entry:** Major tech companies (Apple, Google, Amazon) are already deeply entrenched in      │
# │  wearables, smart home devices, and health data. They possess vast resources, data access, and existing user    │
# │  bases, posing a significant long-term competitive threat if they choose to pivot more directly into this       │
# │  specific diagnostic space.                                                                                     │
# │  5.  **Ethical Considerations:** The potential for increased patient anxiety from early, potentially uncertain  │
# │  diagnoses, the implications of predictive health data on insurance or employment, and ensuring equitable       │
# │  access across different socioeconomic and digital literacy demographics must be carefully addressed.           │
# │                                                                                                                 │
# │  ### Opportunity Score: 8/10                                                                                    │
# │                                                                                                                 │
# │  **Justification:**                                                                                             │
# │                                                                                                                 │
# │  NeuroSense AI targets an enormous and rapidly expanding market driven by the global aging population and the   │
# │  increasing prevalence of neurodegenerative diseases. The problem it seeks to solve – the critical need for     │
# │  early, proactive detection – represents one of the most significant unmet needs in modern medicine. The        │
# │  proposed multi-modal, continuous monitoring approach is highly innovative and holds the potential to be a      │
# │  game-changer, offering a truly differentiated solution compared to existing reactive diagnostic methods. The   │
# │  emphasis on privacy and explainable AI is crucial for building trust and ensuring clinical viability.          │
# │                                                                                                                 │
# │  However, the path to market is fraught with substantial technical, regulatory, and clinical adoption           │
# │  challenges. The complexity of data integration, the immense difficulty in achieving high accuracy with low     │
# │  false positive rates, and the rigorous requirements for medical device approval will demand significant        │
# │  capital, deep scientific expertise, and a long development timeline. Success hinges on meticulous execution,   │
# │  robust clinical validation, strategic partnerships with healthcare systems and technology providers, and a     │
# │  profound commitment to ethical data handling. If these formidable hurdles can be effectively navigated,        │
# │  NeuroSense AI has the potential to not only achieve commercial success but also to fundamentally transform     │
# │  the landscape of neurodegenerative disease management, offering immense societal value. The high score         │
# │  reflects this profound potential, balanced against the significant execution risks.                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Evaluate the proposed startup idea for market demand, competition, and feasibility.                      │
# │  Agent: Market Analyst                                                                                          │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name: Create a simple 5-step execution roadmap for launching this startup.                                     │
# │  ID: 41666743-e8ff-4e91-9c27-900f3bba5923                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Business Planner                                                                                        │
# │                                                                                                                 │
# │  Task: Create a simple 5-step execution roadmap for launching this startup.                                     │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Business Planner                                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Here is a simple 5-step execution roadmap for launching NeuroSense AI:                                         │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# │  **NeuroSense AI: 5-Step Execution Roadmap**                                                                    │
# │                                                                                                                 │
# │  **Step 1: Foundational Research & Minimum Viable Product (MVP) Development**                                   │
# │  *   **Action:** Select a single, high-impact neurodegenerative condition (e.g., early Parkinson's disease or   │
# │  specific Alzheimer's precursor) as the initial focus. Prioritize 1-2 core data streams (e.g., sleep patterns   │
# │  from a specific wearable, typing/voice changes from a smartphone app) that show the strongest early            │
# │  correlation.                                                                                                   │
# │  *   **Outcome:** Develop a proof-of-concept AI model capable of establishing a personalized baseline and       │
# │  detecting statistically significant deviations for the chosen condition and data streams. Establish initial,   │
# │  robust data privacy and security architecture compliant with relevant regulations (e.g., HIPAA, GDPR           │
# │  principles).                                                                                                   │
# │                                                                                                                 │
# │  **Step 2: Clinical Validation & Pilot Program**                                                                │
# │  *   **Action:** Partner with a leading neurology clinic or research institution to conduct a small-scale,      │
# │  Institutional Review Board (IRB)-approved pilot study. Recruit a diverse cohort of participants (healthy       │
# │  controls, at-risk individuals, and early-stage diagnosed patients).                                            │
# │  *   **Outcome:** Gather real-world, longitudinal data to rigorously test the MVP's accuracy (sensitivity,      │
# │  specificity), refine the AI algorithms, and identify initial false positive/negative rates. Collect            │
# │  qualitative feedback from clinicians and patients on usability and perceived value. This step is crucial for   │
# │  demonstrating initial clinical utility and informing regulatory strategy.                                      │
# │                                                                                                                 │
# │  **Step 3: Regulatory Strategy & Full Product Development**                                                     │
# │  *   **Action:** Based on pilot study results, engage medical device regulatory consultants to define the       │
# │  specific classification (e.g., FDA Class II or III, CE Mark) and develop a comprehensive regulatory            │
# │  submission strategy. Simultaneously, expand the AI platform to integrate additional validated data sources     │
# │  (e.g., more wearable types, advanced smartphone analytics) and enhance the explainable AI components.          │
# │  *   **Outcome:** A clear regulatory pathway defined, with a plan for clinical trials. A more robust,           │
# │  multi-modal NeuroSense AI platform with an intuitive user interface for both patients and healthcare           │
# │  providers, ready for larger-scale clinical trials and eventual regulatory submission.                          │
# │                                                                                                                 │
# │  **Step 4: Strategic Partnerships & Reimbursement Planning**                                                    │
# │  *   **Action:** Forge strategic partnerships with key stakeholders: major healthcare systems for clinical      │
# │  integration, leading wearable device manufacturers for deeper data access, and potentially EHR providers for   │
# │  seamless data exchange. Begin proactive discussions with major insurance providers to explore and establish    │
# │  reimbursement pathways for this novel proactive monitoring service.                                            │
# │  *   **Outcome:** Secured agreements or Letters of Intent with clinical partners for future adoption. A         │
# │  well-defined strategy for integrating with existing healthcare workflows and a clear understanding of          │
# │  potential reimbursement models, crucial for market viability.                                                  │
# │                                                                                                                 │
# │  **Step 5: Controlled Launch & Iterative Scaling**                                                              │
# │  *   **Action:** Execute a controlled, phased launch in a specific geographic region or with a select group of  │
# │  early-adopter clinical partners, focusing on the initially targeted condition. Continuously monitor AI         │
# │  performance, clinical outcomes, user experience, and gather feedback.                                          │
# │  *   **Outcome:** Successful initial market penetration and adoption, with proven clinical value and positive   │
# │  user feedback. A data-driven roadmap for iterative product improvements, expansion to additional               │
# │  neurodegenerative conditions, integration of more data streams, and broader market scaling based on            │
# │  regulatory approvals and demonstrated efficacy.                                                                │
# │                                                                                                                 │
# │  ---                                                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: Create a simple 5-step execution roadmap for launching this startup.                                     │
# │  Agent: Business Planner                                                                                        │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ===== FINAL OUTPUT =====
#
# Here is a simple 5-step execution roadmap for launching NeuroSense AI:
#
# ---
#
# **NeuroSense AI: 5-Step Execution Roadmap**
#
# **Step 1: Foundational Research & Minimum Viable Product (MVP) Development**
# *   **Action:** Select a single, high-impact neurodegenerative condition (e.g., early Parkinson's disease or specific Alzheimer's precursor) as the initial focus. Prioritize 1-2 core data streams (e.g., sleep patterns from a specific wearable, typing/voice changes from a smartphone app) that show the strongest early correlation.
# *   **Outcome:** Develop a proof-of-concept AI model capable of establishing a personalized baseline and detecting statistically significant deviations for the chosen condition and data streams. Establish initial, robust data privacy and security architecture compliant with relevant regulations (e.g., HIPAA, GDPR principles).
#
# **Step 2: Clinical Validation & Pilot Program**
# *   **Action:** Partner with a leading neurology clinic or research institution to conduct a small-scale, Institutional Review Board (IRB)-approved pilot study. Recruit a diverse cohort of participants (healthy controls, at-risk individuals, and early-stage diagnosed patients).
# *   **Outcome:** Gather real-world, longitudinal data to rigorously test the MVP's accuracy (sensitivity, specificity), refine the AI algorithms, and identify initial false positive/negative rates. Collect qualitative feedback from clinicians and patients on usability and perceived value. This step is crucial for demonstrating initial clinical utility and informing regulatory strategy.
#
# **Step 3: Regulatory Strategy & Full Product Development**
# *   **Action:** Based on pilot study results, engage medical device regulatory consultants to define the specific classification (e.g., FDA Class II or III, CE Mark) and develop a comprehensive regulatory submission strategy. Simultaneously, expand the AI platform to integrate additional validated data sources (e.g., more wearable types, advanced smartphone analytics) and enhance the explainable AI components.
# *   **Outcome:** A clear regulatory pathway defined, with a plan for clinical trials. A more robust, multi-modal NeuroSense AI platform with an intuitive user interface for both patients and healthcare providers, ready for larger-scale clinical trials and eventual regulatory submission.
#
# **Step 4: Strategic Partnerships & Reimbursement Planning**
# *   **Action:** Forge strategic partnerships with key stakeholders: major healthcare systems for clinical integration, leading wearable device manufacturers for deeper data access, and potentially EHR providers for seamless data exchange. Begin proactive discussions with major insurance providers to explore and establish reimbursement pathways for this novel proactive monitoring service.
# *   **Outcome:** Secured agreements or Letters of Intent with clinical partners for future adoption. A well-defined strategy for integrating with existing healthcare workflows and a clear understanding of potential reimbursement models, crucial for market viability.
#
# **Step 5: Controlled Launch & Iterative Scaling**
# *   **Action:** Execute a controlled, phased launch in a specific geographic region or with a select group of early-adopter clinical partners, focusing on the initially targeted condition. Continuously monitor AI performance, clinical outcomes, user experience, and gather feedback.
# *   **Outcome:** Successful initial market penetration and adoption, with proven clinical value and positive user feedback. A data-driven roadmap for iterative product improvements, expansion to additional neurodegenerative conditions, integration of more data streams, and broader market scaling based on regulatory approvals and demonstrated efficacy.
#
# ---
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
