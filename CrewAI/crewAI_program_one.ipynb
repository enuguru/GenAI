# %%
# !pip install crewai

# %%
import os

os.environ["OPENAI_API_KEY"] = "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" # Replace with your OpenAI API key

# %%
from crewai import Agent, Task, Crew

# -----------------------------
#  Define Agents
# -----------------------------

researcher = Agent(
    name="Researcher",
    role="AI Research Specialist",
    goal="Search and extract relevant insights about the given topic",
    backstory=(
        "You are an expert AI researcher. You find accurate, reliable information"
        " and explain it in simple terms."
    )
)

# %%
writer = Agent(
    name="Writer",
    role="Content Writer",
    goal="Write a clear and concise summary of the topic based on research",
    backstory=(
        "You are a skilled writer who produces engaging and easy-to-understand content."
    )
)

# %%
# -----------------------------
#  Define Tasks
# -----------------------------

research_task = Task(
    description="Research the topic: 'Agentic AI systems and their benefits'",
    agent=researcher,
    expected_output="A list of key insights about agentic AI"
)

write_task = Task(
    description="Using the researcher's insights, write a 3-paragraph summary.",
    agent=writer,
    expected_output="A well-written summary explaining agentic AI systems"
)

# %%
# -----------------------------
#  Create the Crew
# -----------------------------

crew = Crew(
    agents=[researcher, writer],
    tasks=[research_task, write_task],
)

# %%
# -----------------------------
#  Run the Crew
# -----------------------------

result = crew.kickoff()
print("\n\n=== FINAL OUTPUT ===\n")
print(result)
# Out:
# === FINAL OUTPUT ===
#
# Agentic AI systems are artificial intelligence agents characterized by autonomy, decision-making abilities, and goal-directed behavior. They operate by sensing their surroundings, interpreting information, reasoning, and executing actions independently to achieve specific objectives. These systems often function continuously and adaptively, employing planning and learning mechanisms that improve their capabilities over time. Agentic AI includes various types, ranging from simple reactive agents to sophisticated learning and utility-based agents, each designed with different levels of complexity and goal orientation.
#
# ...
